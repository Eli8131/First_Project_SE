# %%
#To load data
import numpy as np
#Data visualization
import matplotlib.dates as mdates
import matplotlib.pyplot as plt
import matplotlib.colors as colors
from mpl_toolkits.axes_grid1 import make_axes_locatable
from matplotlib.ticker import MaxNLocator
import cartopy.crs as ccrs
from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter
import cartopy.feature as cfeature
import cmocean
import cmath

# %%
#import total amplitudes
harmonicA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/A1')
#import phases
harmonicsP1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/P1complex')
harmonicsP2 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/P2')
harmonicsP3 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/P3')
#import monthly A1 amplitudes
janA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/januaryA1')
febA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/februaryA1')
marA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/marchA1')
aprA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/aprilA1')
mayA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/mayA1')
junA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/juneA1')
julA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/julyA1')
augA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/augustA1')
sepA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/septemberA1')
octA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/octoberA1')
novA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/novemberA1')
decA1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/decemberA1')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4832\2838526101.py in <module>
#       2 harmonicA2 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/A2')
#       3 harmonicA3 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/A3')
# ----> 4 harmonicsP1 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/P1complex')
#       5 harmonicsP2 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/P2')
#       6 harmonicsP3 = np.loadtxt('/Users/19082/Desktop/shane/harmonics_data/P3')
#
# c:\Users\19082\miniconda3\lib\site-packages\numpy\lib\npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows, like)
#    1161                 # Convert each value according to its column, then pack it
#    1162                 # according to the dtype's nesting, and store it.
# -> 1163                 chunk.append(packer(convert_row(words)))
#    1164             if not chunk:  # The islice is empty, i.e. we're done.
#    1165                 break
#
# c:\Users\19082\miniconda3\lib\site-packages\numpy\lib\npyio.py in convert_row(vals, _conv)
#    1140             # equal dtypes.
#    1141             def convert_row(vals, _conv=converters[0]):
# -> 1142                 return [*map(_conv, vals)]
#    1143         else:
#    1144             def convert_row(vals):
#
# c:\Users\19082\miniconda3\lib\site-packages\numpy\lib\npyio.py in _floatconv(x)
#     723 def _floatconv(x):
#     724     try:
# --> 725         return float(x)  # The fastest path.
#     726     except ValueError:
#     727         if '0x' in x:  # Don't accidentally convert "a" ("0xa") to 10.
#
# ValueError: could not convert string to float: '(nan+0.000000000000000000e+00j)'

# %%
# Declare bins
lon = np.linspace(-180, 180, 360*2)
lat = np.linspace(-90, 90, 180*2)

# %% [markdown]
# Total Amplitude Plots:

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(harmonicA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    harmonicA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")
# Out:
# Text(0.5, 0, '($^\\circ$C)')

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(harmonicA3,[1,99])

cmap = plt.cm.get_cmap("cmo.thermal", 40)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    harmonicA3,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('A$_3$',);
cb.ax.set_xlabel("($^\circ$C)")
# Out:
# Text(0.5, 0, '($^\\circ$C)')

# %% [markdown]
# Monthly A1 plots:

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(janA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    janA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('January A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(febA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    febA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('February A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4832\1068534290.py in <module>
#       1 #A^iP
# ----> 2 z = complex(harmonicA1, harmonicsP1)
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(marA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    marA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('March A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(aprA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    aprA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('April A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(mayA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    mayA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('May A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(junA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    junA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('June A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(julA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    julA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('July A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(augA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    augA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('August A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(sepA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    sepA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('September A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(octA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    octA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('October A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(novA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    novA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('November A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')

a1, a2 = np.nanpercentile(decA1,[1,99])
cmap = plt.cm.get_cmap("cmo.thermal", 31)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    decA1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('December A$_1$',);
cb.ax.set_xlabel("($^\circ$C)")

# %% [markdown]
# Phase Total Plots:

# %%
x_c = np.convolve(lon, [0.5, 0.5], mode='valid')
y_c = np.convolve(lat, [0.5, 0.5], mode='valid')
a1, a2 = np.nanpercentile(harmonicsP1,[1,99])

cmap = plt.cm.get_cmap("cmo.balance", 40)

fig = plt.figure(dpi=300)
ax = fig.add_subplot(1,1,1,projection=ccrs.Robinson(central_longitude=-180))
pcm = ax.pcolormesh(x_c, y_c, 
                    harmonicsP1,
                    cmap= cmap,
                    transform=ccrs.PlateCarree(),
                    vmin=a1, vmax=a2)

# gridlines and labels
gl = ax.gridlines(color='k', linewidth=0.1, linestyle='-',
                  xlocs=np.arange(-180, 181, 60), ylocs=np.arange(-90, 91, 30),
                  draw_labels=True)
gl.top_labels = False
gl.right_labels = False

# add land and coastline
ax.add_feature(cfeature.LAND, facecolor='grey', zorder=1)
ax.add_feature(cfeature.COASTLINE, linewidth=0.25, zorder=1)
divider = make_axes_locatable(ax)
cax = divider.append_axes("right", size="3%", pad=0.25, axes_class=plt.Axes)
cb = fig.colorbar(pcm, cax=cax, orientation = "vertical");
ax.set_title('P$_1$',);
cb.ax.set_xlabel("($^\circ$C)")
# Out:
# Text(0.5, 0, '($^\\circ$C)')
